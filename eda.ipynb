# %%
import numpy as np
import matplotlib.pyplot as plt
import os, sys
sys.path.append(os.path.dirname(os.path.dirname(os.path.abspath(__file__))))
from util.functions import Bandpass
# Out:
# Running cells with '/Users/arushramteke/miniconda/envs/mlenv/bin/python' requires the ipykernel package.
#
# Run the following command to install 'ipykernel' into the Python environment.
#
# Command: 'conda install -p /Users/arushramteke/miniconda/envs/mlenv ipykernel --update-deps --force-reinstall'

# %%
X_test = np.load("data/X_test.npy")
y_test = np.load("data/y_test.npy")
person_train_valid = np.load("data/person_train_valid.npy")
X_train_valid = np.load("data/X_train_valid.npy")
y_train_valid = np.load("data/y_train_valid.npy")
person_test = np.load("data/person_test.npy")

# %%
fig, ax = plt.subplots(6, 4, figsize=(30, 20))
for i in range(6):
    for j in range(4):
        ax[i,j].plot(np.arange(1000)/250, X_train_valid[i*4 + j][0])

# %%
plt.plot(np.arange(1000), )
